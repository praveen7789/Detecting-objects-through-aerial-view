# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from math import atan
import math
from glob import glob
import re
import pandas as pd
# %matplotlib inline

# %% [markdown]
# |Index|FileName|cov_sobel|cov_thresh|corr_sobel|corr_thresh|angle_max|bird|
# |-----|--------|---------|----------|----------|-----------|---------|----|

# %% [markdown]
#     Step-1: Read image
#     Step-2: Image Gradients
#     Step-3: Computer Cov(sobel), Cov(thresh)
#     Step-4: Angle
#     Step-5: Bird- yes =0, no=0

# %%
def features(image):
    # Step -1 : Extracted non zero values
    x,y = np.nonzero(image)
    # Step -2 : Compute covariance, eigen values and eigen vectos
    cov = np.cov(x,y)
    try:

        evals, evecs = np.linalg.eig(cov)
        # step -4 : Computing correlation
        corr = np.corrcoef(x,y)

        # Step -3: selecting maximum pca variance
        pca_max = np.argmax(evals)
        # Step -4: Angle
        evec = evecs[:,pca_max]
        angle = atan(evec[1]/evec[0])
    except:
        return 0.0, 0.0, 0.0
    
    return cov[0][1], corr[0][1], angle*180/math.pi

# %%
path = glob('./train/*.JPG')
tot = len(path)

# %%
for i in range(len(path)):
    img = Image.open(path[i]) # open image
    img = np.array(img) # convert into array
    blur = cv2.GaussianBlur(img,(5,5),0) # Apply gaussian blur
   gray = cv2.cvtColor(blur,cv2.COLOR_RGB2GRAY) # convert into grayscale
    sobelx = cv2.Sobel(gray,cv2.CV_64F,1,0,ksize=5) # sobel x
    sobely = cv2.Sobel(gray,cv2.CV_64F,0,1,ksize=5) # sobel y
    sobel = cv2.addWeighted(sobelx,0.5,sobely,0.5,0) # sobel = sobel x + sobel y
    sobel_ = np.maximum(sobel,50) # threshold the value to 50
    sobel_[sobel_==50]=0 # collect those values 
    _, thresh = cv2.threshold(sobel_,200,255,cv2.THRESH_BINARY) # apply threshold to sobel

    cov_sobel, corr_sobel, angle_sobel = features(sobel_)
    cov_thresh, corr_thresh, angle_thresh = features(thresh)

    data = {'FileName':path[i],'cov_sobel':cov_sobel,'cov_thresh':cov_thresh,
           'corr_sobel':corr_sobel,'corr_thresh':corr_thresh,
            'angle_sobel':angle_sobel,'angle_thresh':angle_thresh,
           'bird':re.search('_(.*).JPG',path[i]).group(1)}

    df_temp = pd.DataFrame(data=data,index=[i])
    try:
        df = pd.concat((df,df_temp),ignore_index=True)
    except:
        df = df_temp
    print('INFO: innomatics:{}/{} Featues of {} appended sucessfully into dataframe'.format(i+1,tot,path[i]))
# Out:
# INFO: innomatics:1/200 Featues of ./train\100_0.JPG appended sucessfully into dataframe
# INFO: innomatics:2/200 Featues of ./train\100_1.JPG appended sucessfully into dataframe
# INFO: innomatics:3/200 Featues of ./train\10_0.JPG appended sucessfully into dataframe
# INFO: innomatics:4/200 Featues of ./train\10_1.JPG appended sucessfully into dataframe
# INFO: innomatics:5/200 Featues of ./train\11_0.JPG appended sucessfully into dataframe
# INFO: innomatics:6/200 Featues of ./train\11_1.JPG appended sucessfully into dataframe
# INFO: innomatics:7/200 Featues of ./train\12_0.JPG appended sucessfully into dataframe
# INFO: innomatics:8/200 Featues of ./train\12_1.JPG appended sucessfully into dataframe
# INFO: innomatics:9/200 Featues of ./train\13_0.JPG appended sucessfully into dataframe
# INFO: innomatics:10/200 Featues of ./train\13_1.JPG appended sucessfully into dataframe
# INFO: innomatics:11/200 Featues of ./train\14_0.JPG appended sucessfully into dataframe
# INFO: innomatics:12/200 Featues of ./train\14_1.JPG appended sucessfully into dataframe
# INFO: innomatics:13/200 Featues of ./train\15_0.JPG appended sucessfully into dataframe
# INFO: innomatics:14/200 Featues of ./train\15_1.JPG appended sucessfully into dataframe
# INFO: innomatics:15/200 Featues of ./train\16_0.JPG appended sucessfully into dataframe
# INFO: innomatics:16/200 Featues of ./train\16_1.JPG appended sucessfully into dataframe
# INFO: innomatics:17/200 Featues of ./train\17_0.JPG appended sucessfully into dataframe
# INFO: innomatics:18/200 Featues of ./train\17_1.JPG appended sucessfully into dataframe
# C:\Users\Srikanth\Anaconda3\lib\site-packages\numpy\lib\function_base.py:392: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\Srikanth\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\Srikanth\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: Degrees of freedom <= 0 for slice
#   """
# C:\Users\Srikanth\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\Srikanth\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2451: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# INFO: innomatics:19/200 Featues of ./train\18_0.JPG appended sucessfully into dataframe
# INFO: innomatics:20/200 Featues of ./train\18_1.JPG appended sucessfully into dataframe
# INFO: innomatics:21/200 Featues of ./train\19_0.JPG appended sucessfully into dataframe
# INFO: innomatics:22/200 Featues of ./train\19_1.JPG appended sucessfully into dataframe
# INFO: innomatics:23/200 Featues of ./train\1_0.JPG appended sucessfully into dataframe
# INFO: innomatics:24/200 Featues of ./train\1_1.JPG appended sucessfully into dataframe
# INFO: innomatics:25/200 Featues of ./train\20_0.JPG appended sucessfully into dataframe
# INFO: innomatics:26/200 Featues of ./train\20_1.JPG appended sucessfully into dataframe
# INFO: innomatics:27/200 Featues of ./train\21_0.JPG appended sucessfully into dataframe
# INFO: innomatics:28/200 Featues of ./train\21_1.JPG appended sucessfully into dataframe
# INFO: innomatics:29/200 Featues of ./train\22_0.JPG appended sucessfully into dataframe
# INFO: innomatics:30/200 Featues of ./train\22_1.JPG appended sucessfully into dataframe
# INFO: innomatics:31/200 Featues of ./train\23_0.JPG appended sucessfully into dataframe
# INFO: innomatics:32/200 Featues of ./train\23_1.JPG appended sucessfully into dataframe
# INFO: innomatics:33/200 Featues of ./train\24_0.JPG appended sucessfully into dataframe
# INFO: innomatics:34/200 Featues of ./train\24_1.JPG appended sucessfully into dataframe
# INFO: innomatics:35/200 Featues of ./train\25_0.JPG appended sucessfully into dataframe
# INFO: innomatics:36/200 Featues of ./train\25_1.JPG appended sucessfully into dataframe
# INFO: innomatics:37/200 Featues of ./train\26_0.JPG appended sucessfully into dataframe
# INFO: innomatics:38/200 Featues of ./train\26_1.JPG appended sucessfully into dataframe
# INFO: innomatics:39/200 Featues of ./train\27_0.JPG appended sucessfully into dataframe
# INFO: innomatics:40/200 Featues of ./train\27_1.JPG appended sucessfully into dataframe
# INFO: innomatics:41/200 Featues of ./train\28_0.JPG appended sucessfully into dataframe
# INFO: innomatics:42/200 Featues of ./train\28_1.JPG appended sucessfully into dataframe
# INFO: innomatics:43/200 Featues of ./train\29_0.JPG appended sucessfully into dataframe
# INFO: innomatics:44/200 Featues of ./train\29_1.JPG appended sucessfully into dataframe
# INFO: innomatics:45/200 Featues of ./train\2_0.JPG appended sucessfully into dataframe
# INFO: innomatics:46/200 Featues of ./train\2_1.JPG appended sucessfully into dataframe
# INFO: innomatics:47/200 Featues of ./train\30_0.JPG appended sucessfully into dataframe
# INFO: innomatics:48/200 Featues of ./train\30_1.JPG appended sucessfully into dataframe
# INFO: innomatics:49/200 Featues of ./train\31_0.JPG appended sucessfully into dataframe
# INFO: innomatics:50/200 Featues of ./train\31_1.JPG appended sucessfully into dataframe
# INFO: innomatics:51/200 Featues of ./train\32_0.JPG appended sucessfully into dataframe
# INFO: innomatics:52/200 Featues of ./train\32_1.JPG appended sucessfully into dataframe
# INFO: innomatics:53/200 Featues of ./train\33_0.JPG appended sucessfully into dataframe
# INFO: innomatics:54/200 Featues of ./train\33_1.JPG appended sucessfully into dataframe
# INFO: innomatics:55/200 Featues of ./train\34_0.JPG appended sucessfully into dataframe
# INFO: innomatics:56/200 Featues of ./train\34_1.JPG appended sucessfully into dataframe
# INFO: innomatics:57/200 Featues of ./train\35_0.JPG appended sucessfully into dataframe
# INFO: innomatics:58/200 Featues of ./train\35_1.JPG appended sucessfully into dataframe
# INFO: innomatics:59/200 Featues of ./train\36_0.JPG appended sucessfully into dataframe
# INFO: innomatics:60/200 Featues of ./train\36_1.JPG appended sucessfully into dataframe
# INFO: innomatics:61/200 Featues of ./train\37_0.JPG appended sucessfully into dataframe
# INFO: innomatics:62/200 Featues of ./train\37_1.JPG appended sucessfully into dataframe
# INFO: innomatics:63/200 Featues of ./train\38_0.JPG appended sucessfully into dataframe
# INFO: innomatics:64/200 Featues of ./train\38_1.JPG appended sucessfully into dataframe
# INFO: innomatics:65/200 Featues of ./train\39_0.JPG appended sucessfully into dataframe
# INFO: innomatics:66/200 Featues of ./train\39_1.JPG appended sucessfully into dataframe
# INFO: innomatics:67/200 Featues of ./train\3_0.JPG appended sucessfully into dataframe
# INFO: innomatics:68/200 Featues of ./train\3_1.JPG appended sucessfully into dataframe
# INFO: innomatics:69/200 Featues of ./train\40_0.JPG appended sucessfully into dataframe
# INFO: innomatics:70/200 Featues of ./train\40_1.JPG appended sucessfully into dataframe
# INFO: innomatics:71/200 Featues of ./train\41_0.JPG appended sucessfully into dataframe
# INFO: innomatics:72/200 Featues of ./train\41_1.JPG appended sucessfully into dataframe
# INFO: innomatics:73/200 Featues of ./train\42_0.JPG appended sucessfully into dataframe
# INFO: innomatics:74/200 Featues of ./train\42_1.JPG appended sucessfully into dataframe
# INFO: innomatics:75/200 Featues of ./train\43_0.JPG appended sucessfully into dataframe
# INFO: innomatics:76/200 Featues of ./train\43_1.JPG appended sucessfully into dataframe
# INFO: innomatics:77/200 Featues of ./train\44_0.JPG appended sucessfully into dataframe
# INFO: innomatics:78/200 Featues of ./train\44_1.JPG appended sucessfully into dataframe
# INFO: innomatics:79/200 Featues of ./train\45_0.JPG appended sucessfully into dataframe
# INFO: innomatics:80/200 Featues of ./train\45_1.JPG appended sucessfully into dataframe
# INFO: innomatics:81/200 Featues of ./train\46_0.JPG appended sucessfully into dataframe
# INFO: innomatics:82/200 Featues of ./train\46_1.JPG appended sucessfully into dataframe
# INFO: innomatics:83/200 Featues of ./train\47_0.JPG appended sucessfully into dataframe
# INFO: innomatics:84/200 Featues of ./train\47_1.JPG appended sucessfully into dataframe
# INFO: innomatics:85/200 Featues of ./train\48_0.JPG appended sucessfully into dataframe
# INFO: innomatics:86/200 Featues of ./train\48_1.JPG appended sucessfully into dataframe
# INFO: innomatics:87/200 Featues of ./train\49_0.JPG appended sucessfully into dataframe
# INFO: innomatics:88/200 Featues of ./train\49_1.JPG appended sucessfully into dataframe
# INFO: innomatics:89/200 Featues of ./train\4_0.JPG appended sucessfully into dataframe
# INFO: innomatics:90/200 Featues of ./train\4_1.JPG appended sucessfully into dataframe
# INFO: innomatics:91/200 Featues of ./train\50_0.JPG appended sucessfully into dataframe
# INFO: innomatics:92/200 Featues of ./train\50_1.JPG appended sucessfully into dataframe
# INFO: innomatics:93/200 Featues of ./train\51_0.JPG appended sucessfully into dataframe
# INFO: innomatics:94/200 Featues of ./train\51_1.JPG appended sucessfully into dataframe
# INFO: innomatics:95/200 Featues of ./train\52_0.JPG appended sucessfully into dataframe
# INFO: innomatics:96/200 Featues of ./train\52_1.JPG appended sucessfully into dataframe
# INFO: innomatics:97/200 Featues of ./train\53_0.JPG appended sucessfully into dataframe
# INFO: innomatics:98/200 Featues of ./train\53_1.JPG appended sucessfully into dataframe
# INFO: innomatics:99/200 Featues of ./train\54_0.JPG appended sucessfully into dataframe
# INFO: innomatics:100/200 Featues of ./train\54_1.JPG appended sucessfully into dataframe
# INFO: innomatics:101/200 Featues of ./train\55_0.JPG appended sucessfully into dataframe
# INFO: innomatics:102/200 Featues of ./train\55_1.JPG appended sucessfully into dataframe
# INFO: innomatics:103/200 Featues of ./train\56_0.JPG appended sucessfully into dataframe
# INFO: innomatics:104/200 Featues of ./train\56_1.JPG appended sucessfully into dataframe
# INFO: innomatics:105/200 Featues of ./train\57_0.JPG appended sucessfully into dataframe
# INFO: innomatics:106/200 Featues of ./train\57_1.JPG appended sucessfully into dataframe
# INFO: innomatics:107/200 Featues of ./train\58_0.JPG appended sucessfully into dataframe
# INFO: innomatics:108/200 Featues of ./train\58_1.JPG appended sucessfully into dataframe
# INFO: innomatics:109/200 Featues of ./train\59_0.JPG appended sucessfully into dataframe
# INFO: innomatics:110/200 Featues of ./train\59_1.JPG appended sucessfully into dataframe
# INFO: innomatics:111/200 Featues of ./train\5_0.JPG appended sucessfully into dataframe
# INFO: innomatics:112/200 Featues of ./train\5_1.JPG appended sucessfully into dataframe
# INFO: innomatics:113/200 Featues of ./train\60_0.JPG appended sucessfully into dataframe
# INFO: innomatics:114/200 Featues of ./train\60_1.JPG appended sucessfully into dataframe
# INFO: innomatics:115/200 Featues of ./train\61_0.JPG appended sucessfully into dataframe
# INFO: innomatics:116/200 Featues of ./train\61_1.JPG appended sucessfully into dataframe
# INFO: innomatics:117/200 Featues of ./train\62_0.JPG appended sucessfully into dataframe
# INFO: innomatics:118/200 Featues of ./train\62_1.JPG appended sucessfully into dataframe
# INFO: innomatics:119/200 Featues of ./train\63_0.JPG appended sucessfully into dataframe
# INFO: innomatics:120/200 Featues of ./train\63_1.JPG appended sucessfully into dataframe
# INFO: innomatics:121/200 Featues of ./train\64_0.JPG appended sucessfully into dataframe
# INFO: innomatics:122/200 Featues of ./train\64_1.JPG appended sucessfully into dataframe
# INFO: innomatics:123/200 Featues of ./train\65_0.JPG appended sucessfully into dataframe
# INFO: innomatics:124/200 Featues of ./train\65_1.JPG appended sucessfully into dataframe
# INFO: innomatics:125/200 Featues of ./train\66_0.JPG appended sucessfully into dataframe
# INFO: innomatics:126/200 Featues of ./train\66_1.JPG appended sucessfully into dataframe
# INFO: innomatics:127/200 Featues of ./train\67_0.JPG appended sucessfully into dataframe
# INFO: innomatics:128/200 Featues of ./train\67_1.JPG appended sucessfully into dataframe
# INFO: innomatics:129/200 Featues of ./train\68_0.JPG appended sucessfully into dataframe
# INFO: innomatics:130/200 Featues of ./train\68_1.JPG appended sucessfully into dataframe
# INFO: innomatics:131/200 Featues of ./train\69_0.JPG appended sucessfully into dataframe
# INFO: innomatics:132/200 Featues of ./train\69_1.JPG appended sucessfully into dataframe
# INFO: innomatics:133/200 Featues of ./train\6_0.JPG appended sucessfully into dataframe
# INFO: innomatics:134/200 Featues of ./train\6_1.JPG appended sucessfully into dataframe
# INFO: innomatics:135/200 Featues of ./train\70_0.JPG appended sucessfully into dataframe
# INFO: innomatics:136/200 Featues of ./train\70_1.JPG appended sucessfully into dataframe
# INFO: innomatics:137/200 Featues of ./train\71_0.JPG appended sucessfully into dataframe
# INFO: innomatics:138/200 Featues of ./train\71_1.JPG appended sucessfully into dataframe
# INFO: innomatics:139/200 Featues of ./train\72_0.JPG appended sucessfully into dataframe
# INFO: innomatics:140/200 Featues of ./train\72_1.JPG appended sucessfully into dataframe
# INFO: innomatics:141/200 Featues of ./train\73_0.JPG appended sucessfully into dataframe
# INFO: innomatics:142/200 Featues of ./train\73_1.JPG appended sucessfully into dataframe
# INFO: innomatics:143/200 Featues of ./train\74_0.JPG appended sucessfully into dataframe
# INFO: innomatics:144/200 Featues of ./train\74_1.JPG appended sucessfully into dataframe
# INFO: innomatics:145/200 Featues of ./train\75_0.JPG appended sucessfully into dataframe
# INFO: innomatics:146/200 Featues of ./train\75_1.JPG appended sucessfully into dataframe
# INFO: innomatics:147/200 Featues of ./train\76_0.JPG appended sucessfully into dataframe
# INFO: innomatics:148/200 Featues of ./train\76_1.JPG appended sucessfully into dataframe
# INFO: innomatics:149/200 Featues of ./train\77_0.JPG appended sucessfully into dataframe
# INFO: innomatics:150/200 Featues of ./train\77_1.JPG appended sucessfully into dataframe
# INFO: innomatics:151/200 Featues of ./train\78_0.JPG appended sucessfully into dataframe
# INFO: innomatics:152/200 Featues of ./train\78_1.JPG appended sucessfully into dataframe
# INFO: innomatics:153/200 Featues of ./train\79_0.JPG appended sucessfully into dataframe
# INFO: innomatics:154/200 Featues of ./train\79_1.JPG appended sucessfully into dataframe
# INFO: innomatics:155/200 Featues of ./train\7_0.JPG appended sucessfully into dataframe
# INFO: innomatics:156/200 Featues of ./train\7_1.JPG appended sucessfully into dataframe
# INFO: innomatics:157/200 Featues of ./train\80_0.JPG appended sucessfully into dataframe
# INFO: innomatics:158/200 Featues of ./train\80_1.JPG appended sucessfully into dataframe
# INFO: innomatics:159/200 Featues of ./train\81_0.JPG appended sucessfully into dataframe
# INFO: innomatics:160/200 Featues of ./train\81_1.JPG appended sucessfully into dataframe
# INFO: innomatics:161/200 Featues of ./train\82_0.JPG appended sucessfully into dataframe
# INFO: innomatics:162/200 Featues of ./train\82_1.JPG appended sucessfully into dataframe
# INFO: innomatics:163/200 Featues of ./train\83_0.JPG appended sucessfully into dataframe
# INFO: innomatics:164/200 Featues of ./train\83_1.JPG appended sucessfully into dataframe
# INFO: innomatics:165/200 Featues of ./train\84_0.JPG appended sucessfully into dataframe
# INFO: innomatics:166/200 Featues of ./train\84_1.JPG appended sucessfully into dataframe
# INFO: innomatics:167/200 Featues of ./train\85_0.JPG appended sucessfully into dataframe
# INFO: innomatics:168/200 Featues of ./train\85_1.JPG appended sucessfully into dataframe
# INFO: innomatics:169/200 Featues of ./train\86_0.JPG appended sucessfully into dataframe
# C:\Users\Srikanth\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2530: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\Srikanth\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2531: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# INFO: innomatics:170/200 Featues of ./train\86_1.JPG appended sucessfully into dataframe
# INFO: innomatics:171/200 Featues of ./train\87_0.JPG appended sucessfully into dataframe
# INFO: innomatics:172/200 Featues of ./train\87_1.JPG appended sucessfully into dataframe
# INFO: innomatics:173/200 Featues of ./train\88_0.JPG appended sucessfully into dataframe
# INFO: innomatics:174/200 Featues of ./train\88_1.JPG appended sucessfully into dataframe
# INFO: innomatics:175/200 Featues of ./train\89_0.JPG appended sucessfully into dataframe
# INFO: innomatics:176/200 Featues of ./train\89_1.JPG appended sucessfully into dataframe
# INFO: innomatics:177/200 Featues of ./train\8_0.JPG appended sucessfully into dataframe
# INFO: innomatics:178/200 Featues of ./train\8_1.JPG appended sucessfully into dataframe
# INFO: innomatics:179/200 Featues of ./train\90_0.JPG appended sucessfully into dataframe
# INFO: innomatics:180/200 Featues of ./train\90_1.JPG appended sucessfully into dataframe
# INFO: innomatics:181/200 Featues of ./train\91_0.JPG appended sucessfully into dataframe
# INFO: innomatics:182/200 Featues of ./train\91_1.JPG appended sucessfully into dataframe
# INFO: innomatics:183/200 Featues of ./train\92_0.JPG appended sucessfully into dataframe
# INFO: innomatics:184/200 Featues of ./train\92_1.JPG appended sucessfully into dataframe
# INFO: innomatics:185/200 Featues of ./train\93_0.JPG appended sucessfully into dataframe
# INFO: innomatics:186/200 Featues of ./train\93_1.JPG appended sucessfully into dataframe
# INFO: innomatics:187/200 Featues of ./train\94_0.JPG appended sucessfully into dataframe
# INFO: innomatics:188/200 Featues of ./train\94_1.JPG appended sucessfully into dataframe
# INFO: innomatics:189/200 Featues of ./train\95_0.JPG appended sucessfully into dataframe
# INFO: innomatics:190/200 Featues of ./train\95_1.JPG appended sucessfully into dataframe
# INFO: innomatics:191/200 Featues of ./train\96_0.JPG appended sucessfully into dataframe
# INFO: innomatics:192/200 Featues of ./train\96_1.JPG appended sucessfully into dataframe
# INFO: innomatics:193/200 Featues of ./train\97_0.JPG appended sucessfully into dataframe
# INFO: innomatics:194/200 Featues of ./train\97_1.JPG appended sucessfully into dataframe
# INFO: innomatics:195/200 Featues of ./train\98_0.JPG appended sucessfully into dataframe
# INFO: innomatics:196/200 Featues of ./train\98_1.JPG appended sucessfully into dataframe
# INFO: innomatics:197/200 Featues of ./train\99_0.JPG appended sucessfully into dataframe
# INFO: innomatics:198/200 Featues of ./train\99_1.JPG appended sucessfully into dataframe
# INFO: innomatics:199/200 Featues of ./train\9_0.JPG appended sucessfully into dataframe
# INFO: innomatics:200/200 Featues of ./train\9_1.JPG appended sucessfully into dataframe
# C:\Users\Srikanth\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()

# %%
df.head()
# Out:
#             FileName   cov_sobel  cov_thresh  corr_sobel  corr_thresh  \
# 0  ./train\100_0.JPG   72.785440 -419.910123    0.017535    -0.097781
# 1  ./train\100_1.JPG -666.020141 -780.756963   -0.176170    -0.262482
# 2   ./train\10_0.JPG -823.189321    0.000000   -0.178989     0.000000
# 3   ./train\10_1.JPG -217.815641 -444.823813   -0.053471    -0.431951
# 4   ./train\11_0.JPG  134.020925  167.889366    0.032787     0.044236
#
#    angle_sobel  angle_thresh bird
# 0    32.965553    -29.914553    0
# 1   -43.796468    -29.276191    1
# 2   -47.447661      0.000000    0
# 3   -76.567046    -73.930350    1
# 4    45.071667      6.682792    0

# %%
df.to_csv('image_features.csv',index=False)

# %% [markdown]
# Done
#
# ---
